# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('lending_club_loan_two.csv')

# %%
df.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ...  \
# 0                Marketing  10+ years           RENT    117000.0  ...
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...
# 2             Statistician   < 1 year           RENT     43057.0  ...
# 3          Client Advocate    6 years           RENT     54000.0  ...
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...
#
#   open_acc pub_rec revol_bal revol_util total_acc  initial_list_status  \
# 0     16.0     0.0   36369.0       41.8      25.0                    w
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  object
#  13  purpose               396030 non-null  object
# ...

# %%
df.describe().transpose()
# Out:
#                          count          mean           std     min       25%  \
# loan_amnt             396030.0  14113.888089   8357.441341  500.00   8000.00
# int_rate              396030.0     13.639400      4.472157    5.32     10.49
# installment           396030.0    431.849698    250.727790   16.08    250.33
# annual_inc            396030.0  74203.175798  61637.621158    0.00  45000.00
# dti                   396030.0     17.379514     18.019092    0.00     11.28
# open_acc              396030.0     11.311153      5.137649    0.00      8.00
# pub_rec               396030.0      0.178191      0.530671    0.00      0.00
# revol_bal             396030.0  15844.539853  20591.836109    0.00   6025.00
# revol_util            395754.0     53.791749     24.452193    0.00     35.80
# total_acc             396030.0     25.414744     11.886991    2.00     17.00
# mort_acc              358235.0      1.813991      2.147930    0.00      0.00
# ...

# %%
df.notnull().count()
# Out:
# loan_amnt               396030
# term                    396030
# int_rate                396030
# installment             396030
# grade                   396030
# sub_grade               396030
# emp_title               396030
# emp_length              396030
# home_ownership          396030
# annual_inc              396030
# verification_status     396030
# issue_d                 396030
# loan_status             396030
# purpose                 396030
# title                   396030
# dti                     396030
# earliest_cr_line        396030
# open_acc                396030
# pub_rec                 396030
# revol_bal               396030
# revol_util              396030
# total_acc               396030
# initial_list_status     396030
# application_type        396030
# mort_acc                396030
# pub_rec_bankruptcies    396030
# address                 396030
# dtype: int64

# %%
sns.countplot(data=df, x = 'loan_status',hue = 'loan_status')
# Out:
# <Axes: xlabel='loan_status', ylabel='count'>

# %%
df['loan_amnt'].hist()
# Out:
# <Axes: >

# %%
numeric_data_corr=df.corr(numeric_only=True)

# %%
plt.figure(figsize=(10,7))
sns.heatmap(numeric_data_corr,annot=True,cmap='viridis')
# Out:
# <Axes: >

# %%
sns.scatterplot(y='loan_amnt',x='installment',data=df)
# Out:
# <Axes: xlabel='installment', ylabel='loan_amnt'>

# %%
sns.boxplot(x='loan_status',y='loan_amnt',data=df)
# Out:
# <Axes: xlabel='loan_status', ylabel='loan_amnt'>

# %%
df.groupby(by='loan_status')['loan_amnt'].describe()
# Out:
#                 count          mean          std     min     25%      50%  \
# loan_status
# Charged Off   77673.0  15126.300967  8505.090557  1000.0  8525.0  14000.0
# Fully Paid   318357.0  13866.878771  8302.319699   500.0  7500.0  12000.0
#
#                  75%      max
# loan_status
# Charged Off  20000.0  40000.0
# Fully Paid   19225.0  40000.0

# %%
df['grade'].values
# Out:
# array(['B', 'B', 'B', ..., 'B', 'C', 'C'], dtype=object)

# %%
df['sub_grade'].values
# Out:
# array(['B4', 'B5', 'B3', ..., 'B1', 'C2', 'C2'], dtype=object)

# %%
sns.countplot(x='grade',data=df,hue='loan_status')
# Out:
# <Axes: xlabel='grade', ylabel='count'>

# %%
plt.figure(figsize=(12,8))
sorted_order = sorted(df['sub_grade'].unique())
sns.countplot(x='sub_grade',data=df,order=sorted_order,palette='coolwarm')
# Out:
# C:\Users\clyde\AppData\Local\Temp\ipykernel_7064\298035576.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sub_grade',data=df,order=sorted_order,palette='coolwarm')
# <Axes: xlabel='sub_grade', ylabel='count'>

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='sub_grade',data=df,order=sorted_order,palette='coolwarm',hue='loan_status')
# Out:
# <Axes: xlabel='sub_grade', ylabel='count'>

# %%
plt.figure(figsize=(12,8))
isolated_subgrade = sorted_order[25:]
sns.countplot(x='sub_grade',data=df,order=isolated_subgrade,hue='loan_status')
# Out:
# <Axes: xlabel='sub_grade', ylabel='count'>

# %%
def if_paid(status):
    if status == 'Fully Paid':
        return 1
    else:
        return 0

# %%
df['loan_repaid'] = df['loan_status'].apply(if_paid)

# %%
numeric_data_corr['loan_repaid'].sort_values().drop('loan_repaid').plot(kind='bar')
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ... pub_rec  \
# 0                Marketing  10+ years           RENT    117000.0  ...     0.0
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...     0.0
# 2             Statistician   < 1 year           RENT     43057.0  ...     0.0
# 3          Client Advocate    6 years           RENT     54000.0  ...     0.0
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...     0.0
#
#   revol_bal revol_util total_acc initial_list_status  application_type  \
# ...

# %%
len(df)
# Out:
# 396030

# %%
df.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# emp_title               22927
# emp_length              18301
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                    1756
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# loan_repaid                 0
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# loan_amnt               0.000000
# term                    0.000000
# int_rate                0.000000
# installment             0.000000
# grade                   0.000000
# sub_grade               0.000000
# emp_title               5.789208
# emp_length              4.621115
# home_ownership          0.000000
# annual_inc              0.000000
# verification_status     0.000000
# issue_d                 0.000000
# loan_status             0.000000
# purpose                 0.000000
# title                   0.443401
# dti                     0.000000
# earliest_cr_line        0.000000
# open_acc                0.000000
# pub_rec                 0.000000
# revol_bal               0.000000
# revol_util              0.069692
# total_acc               0.000000
# initial_list_status     0.000000
# application_type        0.000000
# mort_acc                9.543469
# pub_rec_bankruptcies    0.135091
# address                 0.000000
# loan_repaid             0.000000
# dtype: float64

# %%
df['emp_title'].nunique()
# Out:
# 173105

# %%
df['emp_length'].nunique()
# Out:
# 11

# %%
df = df.drop('emp_title',axis = 1,)

# %%
emp_length_order = [ '< 1 year',
                      '1 year',
                     '2 years',
                     '3 years',
                     '4 years',
                     '5 years',
                     '6 years',
                     '7 years',
                     '8 years',
                     '9 years',
                     '10+ years']
plt.figure(figsize=(12,8))
sns.countplot(x=df['emp_length'],hue=df['emp_length'],order=emp_length_order,legend=False)
# Out:
# <Axes: xlabel='emp_length', ylabel='count'>

# %%
plt.figure(figsize=(12,8))
sns.countplot(x=df['emp_length'],hue=df['loan_status'],order=emp_length_order)
# Out:
# <Axes: xlabel='emp_length', ylabel='count'>

# %%
length_Charged_off = df['emp_length'][df['loan_status']=='Charged Off'].value_counts()

# %%
length_fully_paid = df['emp_length'][df['loan_status']=='Fully Paid'].value_counts()

# %%
length_loan_status = lenth_Charged_off+lenth_fully_paid

# %%
(length_Charged_off/length_fully_paid).plot(kind='bar')
# Out:
# <Axes: xlabel='emp_length'>

# %%
df = df.drop('emp_length',axis=1)

# %%
df.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                    1756
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# loan_repaid                 0
# dtype: int64

# %%
df['title'].nunique()
# Out:
# 48816

# %%
df = df.drop('title',axis=1)

# %%
df.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# loan_repaid                 0
# dtype: int64

# %%
df['mort_acc'].value_counts()
# Out:
# mort_acc
# 0.0     139777
# 1.0      60416
# 2.0      49948
# 3.0      38049
# 4.0      27887
# 5.0      18194
# 6.0      11069
# 7.0       6052
# 8.0       3121
# 9.0       1656
# 10.0       865
# 11.0       479
# 12.0       264
# 13.0       146
# 14.0       107
# 15.0        61
# 16.0        37
# 17.0        22
# 18.0        18
# 19.0        15
# 20.0        13
# 24.0        10
# 22.0         7
# 21.0         4
# 25.0         4
# 27.0         3
# 32.0         2
# 31.0         2
# 23.0         2
# 26.0         2
# 28.0         1
# 30.0         1
# 34.0         1
# Name: count, dtype: int64

# %%
sorted(df.corr(numeric_only=True)['mort_acc'])
# Out:
# [-0.08258346389179984,
#  -0.025438714276147727,
#  0.00751414134633293,
#  0.011552492126576169,
#  0.027238504697926307,
#  0.07311136643950193,
#  0.10920509829791153,
#  0.1936938084634963,
#  0.19492514684002482,
#  0.22231490100069484,
#  0.2363204015603464,
#  0.38107186658474157,
#  1.0]

# %%
total_acc_avg = df.groupby('total_acc')['mort_acc'].mean()
total_acc_avg
# Out:
# total_acc
# 2.0      0.000000
# 3.0      0.052023
# 4.0      0.066743
# 5.0      0.103289
# 6.0      0.151293
#            ...
# 124.0    1.000000
# 129.0    1.000000
# 135.0    3.000000
# 150.0    2.000000
# 151.0    0.000000
# Name: mort_acc, Length: 118, dtype: float64

# %%
total_acc_avg[2.0]
# Out:
# 0.0

# %%
def add_missing_value(mort_val, total_val):
    if np.isnan(mort_val):
        return total_acc_avg[total_val]
    else:
        return mort_val

# %%
df['mort_acc'] = df.apply(lambda x: add_missing_value(x['mort_acc'],x['total_acc']),axis = 1)

# %%
df.isnull().sum()
# Out:
# loan_amnt                 0
# term                      0
# int_rate                  0
# installment               0
# grade                     0
# sub_grade                 0
# home_ownership            0
# annual_inc                0
# verification_status       0
# issue_d                   0
# loan_status               0
# purpose                   0
# dti                       0
# earliest_cr_line          0
# open_acc                  0
# pub_rec                   0
# revol_bal                 0
# revol_util              276
# total_acc                 0
# initial_list_status       0
# application_type          0
# mort_acc                  0
# pub_rec_bankruptcies    535
# address                   0
# loan_repaid               0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# loan_amnt               0
# term                    0
# int_rate                0
# installment             0
# grade                   0
# sub_grade               0
# home_ownership          0
# annual_inc              0
# verification_status     0
# issue_d                 0
# loan_status             0
# purpose                 0
# dti                     0
# earliest_cr_line        0
# open_acc                0
# pub_rec                 0
# revol_bal               0
# revol_util              0
# total_acc               0
# initial_list_status     0
# application_type        0
# mort_acc                0
# pub_rec_bankruptcies    0
# address                 0
# loan_repaid             0
# dtype: int64

# %%
df.select_dtypes('object').columns
# Out:
# Index(['term', 'grade', 'sub_grade', 'home_ownership', 'verification_status',
#        'issue_d', 'loan_status', 'purpose', 'earliest_cr_line',
#        'initial_list_status', 'application_type', 'address'],
#       dtype='object')

# %%
def to_integer(months):
    number = months[0:3]
    return(int(number))

# %%
df['term'] = df.apply(lambda x : to_integer(x['term']), axis = 1)
# Out:
# C:\Users\clyde\AppData\Local\Temp\ipykernel_7064\99524078.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['term'] = df.apply(lambda x : to_integer(x['term']), axis = 1)

# %%
df = df.drop('grade',axis = 1)

# %%
sub_grade_dummies = pd.get_dummies(drop_first=True, data = df['sub_grade'])

# %%
#df = pd.concat([df.drop('sub_grade',axis = 1),sub_grade_dummies],axis=1)

# %%
df.select_dtypes('object').columns
# Out:
# Index(['home_ownership', 'verification_status', 'issue_d', 'loan_status',
#        'purpose', 'earliest_cr_line', 'initial_list_status',
#        'application_type', 'address'],
#       dtype='object')

# %%
import pandas as pd

# %%
verification_status_dummies = pd.get_dummies(drop_first=True, data = df['verification_status'])
application_type_dummies = pd.get_dummies(drop_first=True, data = df['application_type'])
initial_list_status_dummies = pd.get_dummies(drop_first=True, data = df['initial_list_status'])
purpose_dummies = pd.get_dummies(drop_first=True, data = df['purpose'])

# %%
df = pd.concat([df.drop(['verification_status','application_type','initial_list_status','purpose'],axis = 1),
           verification_status_dummies,application_type_dummies,initial_list_status_dummies,purpose_dummies],axis=1)

# %%
df['home_ownership'].value_counts()
# Out:
# home_ownership
# MORTGAGE    198022
# RENT        159395
# OWN          37660
# OTHER          110
# NONE            29
# ANY              3
# Name: count, dtype: int64

# %%
def to_other(type):
    if type == 'NONE' or type == 'ANY':
        return 'OTHER'
    else:
        return type

# %%
df['home_ownership'] = df.apply(lambda x : to_other(x['home_ownership']), axis = 1)

# %%
home_ownership_dummies = pd.get_dummies(df['home_ownership'], drop_first=True)

# %%
df = pd.concat([df.drop('home_ownership', axis = 1), home_ownership_dummies],axis=1)

# %%
# Out:
# address
# USCGC Smith\nFPO AE 70466                            8
# USS Smith\nFPO AP 70466                              8
# USS Johnson\nFPO AE 48052                            8
# USNS Johnson\nFPO AE 05113                           8
# USNS Johnson\nFPO AP 48052                           7
#                                                     ..
# 43570 Maxwell Field Apt. 502\nEast John, NH 22690    1
# 9983 Turner Cove\nSouth Gregmouth, WV 70466          1
# 1312 Cody Shoal\nRalphfurt, CO 29597                 1
# 3841 Liu Crest\nClarkchester, NC 29597               1
# 787 Michelle Causeway\nBriannaton, AR 48052          1
# Name: count, Length: 392898, dtype: int64

# %%
df['zip_code'] = df.apply(lambda x : x['address'][-5:],axis = 1)

# %%
df['zip_code'].head(100)
# Out:
# 0     22690
# 1     05113
# 2     05113
# 3     00813
# 4     11650
#       ...
# 95    70466
# 96    00813
# 97    93700
# 98    48052
# 99    70466
# Name: zip_code, Length: 100, dtype: object

# %%
zip_code_dummies = pd.get_dummies(df['zip_code'], drop_first = True)

# %%
pd = pd.concat([df.drop(['zip_code','address'],axis = 1),zip_code_dummies],axis = 1 )

# %%
df = pd

# %%
import pandas as pd

# %%
df = df.drop('issue_d',axis = 1)

# %%
df['earliest_cr_year']= df.apply(lambda x: int(x['earliest_cr_line'][-4:]), axis = 1 )

# %%
df.drop('earliest_cr_line',axis=1,inplace=True)

# %%
df
# Out:
#         loan_amnt  term  int_rate  installment  annual_inc  loan_status  \
# 0         10000.0    36     11.44       329.48    117000.0   Fully Paid
# 1          8000.0    36     11.99       265.68     65000.0   Fully Paid
# 2         15600.0    36     10.49       506.97     43057.0   Fully Paid
# 3          7200.0    36      6.49       220.65     54000.0   Fully Paid
# 4         24375.0    60     17.27       609.33     55000.0  Charged Off
# ...           ...   ...       ...          ...         ...          ...
# 396025    10000.0    60     10.99       217.38     40000.0   Fully Paid
# 396026    21000.0    36     12.29       700.42    110000.0   Fully Paid
# 396027     5000.0    36      9.99       161.32     56500.0   Fully Paid
# 396028    21000.0    60     15.31       503.02     64000.0   Fully Paid
# 396029     2000.0    36     13.61        67.98     42996.0   Fully Paid
#
#           dti  open_acc  pub_rec  revol_bal  ...  05113  11650  22690  29597  \
# ...

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['loan_status'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
df.drop('loan_status',axis=1,inplace=True)

# %%
X = df.drop('loan_repaid',axis=1,)
y = df['loan_repaid']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler(feature_range=(0,1))

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.models import Sequential

# %%
model = Sequential()

model.add(Dense(78,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(39,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(19,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam')

# %%
model.fit(x = X_train,y = y_train,batch_size = 256,epochs = 25,validation_data = (X_test,y_test))
# Out:
# Epoch 1/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.3089 - val_loss: 0.2642
# Epoch 2/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2670 - val_loss: 0.2637
# Epoch 3/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2638 - val_loss: 0.2624
# Epoch 4/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2624 - val_loss: 0.2625
# Epoch 5/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2613 - val_loss: 0.2618
# Epoch 6/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2606 - val_loss: 0.2618
# Epoch 7/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2601 - val_loss: 0.2615
# Epoch 8/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2597 - val_loss: 0.2611
# Epoch 9/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2595 - val_loss: 0.2622
# Epoch 10/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2592 - val_loss: 0.2614
# Epoch 11/25
# ...

# %%
loss =  pd.DataFrame(model.history.history)

# %%
loss.plot()
# Out:
# <Axes: >

# %%
predictions = (model.predict(X_test) > 0.5)*1
# Out:
# 2471/2471 ━━━━━━━━━━━━━━━━━━━━ 2s 730us/step

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(classification_report(y_test,predictions))
print(confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.46      0.62     15658
#            1       0.88      0.99      0.93     63386
#
#     accuracy                           0.89     79044
#    macro avg       0.91      0.73      0.78     79044
# weighted avg       0.89      0.89      0.87     79044
#
# [[ 7198  8460]
#  [  415 62971]]

# %%
import random
random.seed(101)
random_ind = random.randint(0,len(df))

new_customer = df.drop('loan_repaid',axis=1).iloc[random_ind]

new_customer = new_customer.astype(float)
new_customer
# Out:
# loan_amnt           25000.00
# term                   60.00
# int_rate               18.24
# installment           638.11
# annual_inc          61665.00
#                       ...
# 48052                   0.00
# 70466                   0.00
# 86630                   0.00
# 93700                   0.00
# earliest_cr_year     1996.00
# Name: 305323, Length: 78, dtype: float64

# %%
(model.predict(new_customer.values.reshape(1,78)) > 0.5)*1
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# array([[1]])

# %%
df.iloc[random_ind]['loan_repaid']
# Out:
# 1

# %%
model.save('loan_payback_model.keras')
